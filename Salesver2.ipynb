# %% [markdown]
# ## Task 1 : import packages and load file

# %%
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np

filename = input('Please input file name: ')
dataframe = pd.read_csv (filename)
dataframe.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ## Task 2 : Clean and process data

# %% [markdown]
# ### Task 2.1 Merge 12 csv files

# %%
os.listdir(path)
# Out:
# ['sales2019_1.csv',
#  'sales2019_10.csv',
#  'sales2019_11.csv',
#  'sales2019_12.csv',
#  'sales2019_2.csv',
#  'sales2019_3.csv',
#  'sales2019_4.csv',
#  'sales2019_5.csv',
#  'sales2019_6.csv',
#  'sales2019_7.csv',
#  'sales2019_8.csv',
#  'sales2019_9.csv']

# %%
frames = []
all_length = []
for file in os.listdir(path) :
    if file.endswith('.csv') : 
        filepath = os.path.join(path,file)
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)
        length_1month = len(df1.index)
        all_length.append(length_1month)
df = result
df.to_csv('annualsales2019.csv', index = False)

# %%
print(sum(all_length))
# Out:
# 186850

# %%
df.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   141234                      iPhone                1        700
# 1   141235    Lightning Charging Cable                1      14.95
# 2   141236            Wired Headphones                2      11.99
# 3   141237            27in FHD Monitor                1     149.99
# 4   141238            Wired Headphones                1      11.99
# 5   141239      AAA Batteries (4-pack)                1       2.99
# 6   141240      27in 4K Gaming Monitor                1     389.99
# 7   141241        USB-C Charging Cable                1      11.95
# 8   141242  Bose SoundSport Headphones                1      99.99
# 9   141243    Apple Airpods Headphones                1        150
#
#        Order Date                         Purchase Address
# 0  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59            387 10th St, Austin, TX 73301
# 5  01/29/19 20:22   775 Willow St, San Francisco, CA 94016
# 6  01/26/19 12:16       979 Park St, Los Angeles, CA 90001
# 7  01/05/19 12:04      181 6th St, San Francisco, CA 94016
# 8  01/01/19 10:30     867 Willow St, Los Angeles, CA 90001
# 9  01/22/19 21:20  657 Johnson St, San Francisco, CA 94016

# %%
df['Month'] = df['Order Date'].str.slice(0,2,1)
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [186850 rows x 7 columns]

# %%
print(set(df['Month']))
# Out:
# {'03', '09', '06', '01', '07', 'Or', '08', nan, '10', '11', '04', '05', '02', '12'}

# %% [markdown]
# ## Task 2.3 : Get rid of 'Nan' and 'Or'value

# %%
df = df.dropna(how='all')
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [186305 rows x 7 columns]

# %%
df= df[df['Month']!='Or']
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [185950 rows x 7 columns]

# %% [markdown]
# ## Task 3 : Reporting

# %% [markdown]
# Task 3.1 : What was the best month for sales ? How much was earned that month?

# %%
df.head(5)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
print(df['Quantity Ordered'].dtypes)
print(df['Price Each'].dtypes)
# Out:
# object
# object

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'],downcast='integer')
df['Price Each'] = pd.to_numeric(df['Price Each'],downcast='float')
# Out:
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\4097673364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'],downcast='integer')
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\4097673364.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price Each'] = pd.to_numeric(df['Price Each'],downcast='float')

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\500589919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales'] = df['Quantity Ordered'] * df['Price Each']
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#        Order Date                       Purchase Address Month       Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01  700.000000
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01   14.950000
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01   23.980000
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01  149.990005
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01   11.990000

# %%
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#            Order Date                         Purchase Address Month  \
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#             Sales
# 0      700.000000
# 1       14.950000
# 2       23.980000
# 3      149.990005
# 4       11.990000
# ...           ...
# 11681    8.970000
# 11682  700.000000
# 11683  700.000000
# 11684  379.989990
# 11685   11.950000
#
# [185950 rows x 8 columns]

# %%
sale_value = df.groupby('Month').sum()['Sales']
sale_value.max()
# Out:
# 4613443.5

# %%
months = range(1,13)
plt.bar(x=months, height=sale_value, align='center')
plt.xticks(months)
plt.xlabel('Month')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# ## Task 3.2 : What city has the best sales

# %%
df.head(10)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   141234                      iPhone                 1  700.000000
# 1   141235    Lightning Charging Cable                 1   14.950000
# 2   141236            Wired Headphones                 2   11.990000
# 3   141237            27in FHD Monitor                 1  149.990005
# 4   141238            Wired Headphones                 1   11.990000
# 5   141239      AAA Batteries (4-pack)                 1    2.990000
# 6   141240      27in 4K Gaming Monitor                 1  389.989990
# 7   141241        USB-C Charging Cable                 1   11.950000
# 8   141242  Bose SoundSport Headphones                 1   99.989998
# 9   141243    Apple Airpods Headphones                 1  150.000000
#
#        Order Date                         Purchase Address Month       Sales
# 0  01/22/19 21:25          944 Walnut St, Boston, MA 02215    01  700.000000
# 1  01/28/19 14:15         185 Maple St, Portland, OR 97035    01   14.950000
# 2  01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01   23.980000
# 3  01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01  149.990005
# 4  01/25/19 11:59            387 10th St, Austin, TX 73301    01   11.990000
# 5  01/29/19 20:22   775 Willow St, San Francisco, CA 94016    01    2.990000
# 6  01/26/19 12:16       979 Park St, Los Angeles, CA 90001    01  389.989990
# 7  01/05/19 12:04      181 6th St, San Francisco, CA 94016    01   11.950000
# 8  01/01/19 10:30     867 Willow St, Los Angeles, CA 90001    01   99.989998
# 9  01/22/19 21:20  657 Johnson St, San Francisco, CA 94016    01  150.000000

# %%
df['City'] = df['Purchase Address'].str.split(",",expand=True)[1]
df
# Out:
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\3828920749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] = df['Purchase Address'].str.split(",",expand=True)[1]
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#            Order Date                         Purchase Address Month  \
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035    01
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016    01
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001    01
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301    01
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
#             Sales            City
# 0      700.000000          Boston
# 1       14.950000        Portland
# 2       23.980000   San Francisco
# 3      149.990005     Los Angeles
# 4       11.990000          Austin
# ...           ...             ...
# 11681    8.970000     Los Angeles
# 11682  700.000000   San Francisco
# 11683  700.000000   San Francisco
# 11684  379.989990   San Francisco
# 11685   11.950000   San Francisco
#
# [185950 rows x 9 columns]

# %%
City_sales = df.groupby('City').sum('Sales')['Sales']
City_sales.sort_values(ascending=False)
# Out:
# City
# San Francisco    8262204.00
# Los Angeles      5452571.00
# New York City    4664317.50
# Boston           3661642.00
# Atlanta          2795498.50
# Dallas           2767975.50
# Seattle          2747755.50
# Portland         2320490.50
# Austin           1819581.75
# Name: Sales, dtype: float32

# %%
City_sales.max()
# Out:
# 8262204.0

# %%
cities = []
for city, sales in City_sales.items() :
    cities.append(city)
print(cities)
# Out:
# [' Atlanta', ' Austin', ' Boston', ' Dallas', ' Los Angeles', ' New York City', ' Portland', ' San Francisco', ' Seattle']

# %%
plt.bar(x= cities, height=City_sales, align='center')
plt.xticks(cities, rotation = 45, size = 8 )
plt.xlabel('Cities')
plt.ylabel('City_Sales')
plt.show()

# %% [markdown]
# ## Task 3.3 : What time should we display ads to maximize the likelihood of customer's buying product?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#        Order Date                       Purchase Address Month       Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01  700.000000
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01   14.950000
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01   23.980000
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01  149.990005
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01   11.990000
#
#              City
# 0          Boston
# 1        Portland
# 2   San Francisco
# 3     Los Angeles
# 4          Austin

# %%
print(df['Order Date'].dtype)
# Out:
# object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\1044256253.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\1044256253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#            Order Date                       Purchase Address Month  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    01
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    01
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    01
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    01
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    01
#
#         Sales            City
# 0  700.000000          Boston
# 1   14.950000        Portland
# 2   23.980000   San Francisco
# 3  149.990005     Los Angeles
# 4   11.990000          Austin

# %%
df['Hour'] = df['Order Date'].dt.hour

df.head()
# Out:
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\3670712917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df['Order Date'].dt.hour
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#            Order Date                       Purchase Address Month  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    01
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    01
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    01
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    01
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    01
#
#         Sales            City  Hour
# 0  700.000000          Boston    21
# 1   14.950000        Portland    14
# 2   23.980000   San Francisco    13
# 3  149.990005     Los Angeles    20
# 4   11.990000          Austin    11

# %%
del df['Hour']

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#            Order Date                       Purchase Address Month  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    01
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    01
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    01
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    01
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    01
#
#         Sales            City
# 0  700.000000          Boston
# 1   14.950000        Portland
# 2   23.980000   San Francisco
# 3  149.990005     Los Angeles
# 4   11.990000          Austin

# %%
sales_by_hour = df.groupby('Hours')['Sales'].sum()

hour_posted = [hour for hour, sales in sales_by_hour.items()]

plt.plot(hour_posted, sales_by_hour)
plt.grid()
plt.xticks(hour_posted, rotation = 90, size = 8 )
plt.xlabel('Hour')
plt.ylabel('Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sales_by_hour = df.groupby('Hours')['Sales'].sum()
#       3 hour_posted = [hour for hour, sales in sales_by_hour.items()]
#       5 plt.plot(hour_posted, sales_by_hour)
#
# File c:\Users\ngocc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9156, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9153 if level is None and by is None:
#    9154     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9156 return DataFrameGroupBy(
#    9157     obj=self,
#    9158     keys=by,
#    9159     axis=axis,
#    9160     level=level,
#    9161     as_index=as_index,
#    9162     sort=sort,
#    9163     group_keys=group_keys,
#    9164     observed=observed,
#    9165     dropna=dropna,
#    9166 )
#
# File c:\Users\ngocc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\ngocc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Hours'

# %%
sales_by_hour = df.groupby('Hours')['Sales'].count()

hour_posted = [hour for hour, sales in sales_by_hour.items()]

plt.plot(hour_posted, sales_by_hour)
plt.grid()
plt.xticks(hour_posted, rotation = 90, size = 8 )
plt.xlabel('Hour')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Task 3.4 what products are most often sold together

# %%
df.head(10)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   141234                      iPhone                 1  700.000000
# 1   141235    Lightning Charging Cable                 1   14.950000
# 2   141236            Wired Headphones                 2   11.990000
# 3   141237            27in FHD Monitor                 1  149.990005
# 4   141238            Wired Headphones                 1   11.990000
# 5   141239      AAA Batteries (4-pack)                 1    2.990000
# 6   141240      27in 4K Gaming Monitor                 1  389.989990
# 7   141241        USB-C Charging Cable                 1   11.950000
# 8   141242  Bose SoundSport Headphones                 1   99.989998
# 9   141243    Apple Airpods Headphones                 1  150.000000
#
#            Order Date                         Purchase Address Month  \
# 0 2019-01-22 21:25:00          944 Walnut St, Boston, MA 02215    01
# 1 2019-01-28 14:15:00         185 Maple St, Portland, OR 97035    01
# 2 2019-01-17 13:33:00    538 Adams St, San Francisco, CA 94016    01
# 3 2019-01-05 20:33:00       738 10th St, Los Angeles, CA 90001    01
# 4 2019-01-25 11:59:00            387 10th St, Austin, TX 73301    01
# 5 2019-01-29 20:22:00   775 Willow St, San Francisco, CA 94016    01
# 6 2019-01-26 12:16:00       979 Park St, Los Angeles, CA 90001    01
# 7 2019-01-05 12:04:00      181 6th St, San Francisco, CA 94016    01
# 8 2019-01-01 10:30:00     867 Willow St, Los Angeles, CA 90001    01
# 9 2019-01-22 21:20:00  657 Johnson St, San Francisco, CA 94016    01
#
#         Sales            City  Hours
# 0  700.000000          Boston     21
# 1   14.950000        Portland     14
# 2   23.980000   San Francisco     13
# 3  149.990005     Los Angeles     20
# 4   11.990000          Austin     11
# 5    2.990000   San Francisco     20
# 6  389.989990     Los Angeles     12
# 7   11.950000   San Francisco     12
# 8   99.989998     Los Angeles     10
# 9  150.000000   San Francisco     21

# %%
order_dup = df[df['Order ID'].duplicated(keep = False)]
order_dup.head()
# Out:
#     Order ID                   Product  Quantity Ordered  Price Each  \
# 41    141275      USB-C Charging Cable                 1       11.95
# 42    141275          Wired Headphones                 1       11.99
# 57    141290  Apple Airpods Headphones                 1      150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84
# 133   141365           Vareebadd Phone                 1      400.00
#
#              Order Date                        Purchase Address Month   Sales  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01   11.95
# 42  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01   11.99
# 57  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01  150.00
# 58  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01   11.52
# 133 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001    01  400.00
#
#                City
# 41           Austin
# 42           Austin
# 57      Los Angeles
# 58      Los Angeles
# 133   New York City

# %%
groupproduct = lambda product : ', '.join(product)
order_dup['All Products'] =  order_dup.groupby('Order ID')['Product'].transform(groupproduct)
order_dup.head()
# Out:
# C:\Users\ngocc\AppData\Local\Temp\ipykernel_17884\3032414794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   order_dup['All Products'] =  order_dup.groupby('Order ID')['Product'].transform(groupproduct)
#     Order ID                   Product  Quantity Ordered  Price Each  \
# 41    141275      USB-C Charging Cable                 1       11.95
# 42    141275          Wired Headphones                 1       11.99
# 57    141290  Apple Airpods Headphones                 1      150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84
# 133   141365           Vareebadd Phone                 1      400.00
#
#              Order Date                        Purchase Address Month   Sales  \
# 41  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01   11.95
# 42  2019-01-07 16:06:00         610 Walnut St, Austin, TX 73301    01   11.99
# 57  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01  150.00
# 58  2019-01-02 08:25:00         4 1st St, Los Angeles, CA 90001    01   11.52
# 133 2019-01-10 11:19:00  20 Dogwood St, New York City, NY 10001    01  400.00
#
#                City                                     All Products
# 41           Austin           USB-C Charging Cable, Wired Headphones
# 42           Austin           USB-C Charging Cable, Wired Headphones
# 57      Los Angeles  Apple Airpods Headphones, AA Batteries (4-pack)
# 58      Los Angeles  Apple Airpods Headphones, AA Batteries (4-pack)
# 133   New York City                Vareebadd Phone, Wired Headphones

# %%
order_dup = order_dup[['Order ID','All Products']].drop_duplicates()
order_dup.head()
# Out:
#     Order ID                                     All Products
# 41    141275           USB-C Charging Cable, Wired Headphones
# 57    141290  Apple Airpods Headphones, AA Batteries (4-pack)
# 133   141365                Vareebadd Phone, Wired Headphones
# 153   141384               Google Phone, USB-C Charging Cable
# 220   141450         Google Phone, Bose SoundSport Headphones

# %%
order_dup['All Products'].value_counts(ascending = False)
# Out:
# All Products
# iPhone, Lightning Charging Cable                        882
# Google Phone, USB-C Charging Cable                      856
# iPhone, Wired Headphones                                361
# Vareebadd Phone, USB-C Charging Cable                   312
# Google Phone, Wired Headphones                          303
#                                                        ...
# Vareebadd Phone, Wired Headphones, iPhone                 1
# Google Phone, Wired Headphones, USB-C Charging Cable      1
# LG Washing Machine, Wired Headphones                      1
# LG Washing Machine, Google Phone                          1
# LG Washing Machine, AA Batteries (4-pack)                 1
# Name: count, Length: 366, dtype: int64

# %% [markdown]
# ## Task 3.5: What product sold the most? Why do you think it sold the most?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#            Order Date                       Purchase Address Month  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    01
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    01
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    01
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    01
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    01
#
#         Sales            City
# 0  700.000000          Boston
# 1   14.950000        Portland
# 2   23.980000   San Francisco
# 3  149.990005     Los Angeles
# 4   11.990000          Austin

# %%
total_qty_product = df.groupby('Product')['Quantity Ordered'].sum().sort_values(ascending = True)
total_qty_product
# Out:
# Product
# LG Dryer                        646
# LG Washing Machine              666
# Vareebadd Phone                2068
# 20in Monitor                   4129
# ThinkPad Laptop                4130
# Macbook Pro Laptop             4728
# Flatscreen TV                  4819
# Google Phone                   5532
# 34in Ultrawide Monitor         6199
# 27in 4K Gaming Monitor         6244
# iPhone                         6849
# 27in FHD Monitor               7550
# Bose SoundSport Headphones    13457
# Apple Airpods Headphones      15661
# Wired Headphones              20557
# Lightning Charging Cable      23217
# USB-C Charging Cable          23975
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Name: Quantity Ordered, dtype: int64

# %%
Product_name = [Product for Product, quantity in total_qty_product.items()]

plt.bar(Product_name,total_qty_product)
plt.xticks(Product_name, rotation = 90, size = 8 )
plt.xlabel('Product')
plt.ylabel('Quantity Ordered')
plt.title('TOtal Order')
plt.show()

# %% [markdown]
# Why?

# %%
prices = df.groupby('Product')['Price Each'].mean()
prices.head()
# Out:
# Product
# 20in Monitor              109.989998
# 27in 4K Gaming Monitor    389.990021
# 27in FHD Monitor          149.990005
# 34in Ultrawide Monitor    379.990021
# AA Batteries (4-pack)       3.840000
# Name: Price Each, dtype: float32

# %%
x = Product_name
y1 = total_qty_product
y2 = prices

fig,ax1 = plt.subplots()
ax1.bar(x,y1,color='green')
ax1.set_xlabel('Product_name')
plt.xticks(Product_name, rotation = 90, size = 8 )
ax1.set_ylabel('Total Qty Ordered')
ax2 = ax1.twinx()
ax2.plot(x,y2,'-b')
ax2.set_ylabel('Price')
plt.title('Price vs Product_Sold')

plt.show()
